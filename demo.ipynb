# %% [markdown]
# # Import packages

# %%
import torch
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from denoiser import fft_denoising

# %% [markdown]
# # Load sample

# %%
# Read all the files
folder_path = 'samples'
files = os.listdir(folder_path)

# Select the file/sample to analyze
selected_file = 1
file = files[selected_file - 1]
print(file, files)
# Out:
# twin1.tif ['twin1.tif', 'twin2.tif', 'twin3.tif']

# %%
image = np.array(Image.open(f'{folder_path}/{file}'))

plt.imshow(image, cmap = 'gray')
plt.show()

# %% [markdown]
# # Load model

# %%
dl_model = torch.load('models/DL2.pt')

# %% [markdown]
# # Denoise

# %%
dic_process = fft_denoising(image, all_process = True)
process = list(dic_process.values())

for title, image in dic_process.items():
    plt.imshow(image, cmap='gray')
    plt.title(title)
    plt.show()
